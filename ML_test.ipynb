# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn import model_selection
from sklearn.metrics import accuracy_score
import xgboost as xgb
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Train data

# %%
path_to_data = r"C:\Users\meghn\Documents\Dauphine\Master\M2 Finance Quantitative\Semestre 2\Machine Learning\data\\"
train_home_team_statistics_df = pd.read_csv(path_to_data+'Train_Data/train_home_team_statistics_df.csv', index_col=0)
train_away_team_statistics_df = pd.read_csv(path_to_data+'Train_Data/train_home_team_statistics_df.csv', index_col=0)
train_scores = pd.read_csv(path_to_data+'Y_train_1rknArQ.csv', index_col=0)

train_home = train_home_team_statistics_df.iloc[:,2:]
train_away = train_away_team_statistics_df.iloc[:,2:]

train_home.columns = 'HOME_' + train_home.columns
train_away.columns = 'AWAY_' + train_away.columns

train_data =  pd.concat([train_home,train_away],join='inner',axis=1)
train_scores = train_scores.loc[train_data.index]

train_data = train_data.replace({np.inf:np.nan,-np.inf:np.nan})

# %%
train_home_team_statistics_df.head()
# Out:
#             LEAGUE                TEAM_NAME  TEAM_SHOTS_TOTAL_season_sum  \
# ID
# 0          Ligue 1                 Toulouse                          3.0
# 1          Ligue 2                    Brest                          6.0
# 2          Serie A                Sampdoria                          4.0
# 3       League One            Coventry City                          7.0
# 4   Premier League  Wolverhampton Wanderers                          3.0
#
#     TEAM_SHOTS_INSIDEBOX_season_sum  TEAM_SHOTS_OFF_TARGET_season_sum  \
# ID
# 0                               2.0                               5.0
# 1                               8.0                               3.0
# 2                               2.0                               5.0
# 3                               5.0                               5.0
# 4                               3.0                               2.0
#
#     TEAM_SHOTS_ON_TARGET_season_sum  TEAM_SHOTS_OUTSIDEBOX_season_sum  \
# ID
# 0                               2.0                               1.0
# 1                               6.0                               5.0
# 2                               2.0                               8.0
# 3                               6.0                               6.0
# 4                               3.0                               4.0
#
#     TEAM_PASSES_season_sum  TEAM_SUCCESSFUL_PASSES_season_sum  \
# ID
# 0                      2.0                                2.0
# 1                      8.0                                7.0
# 2                      1.0                                1.0
# 3                      9.0                                9.0
# 4                      4.0                                3.0
#
#     TEAM_SAVES_season_sum  ...  TEAM_YELLOWCARDS_5_last_match_std  \
# ID                         ...
# 0                     5.0  ...                                3.0
# 1                    10.0  ...                                4.0
# 2                     2.0  ...                                4.0
# 3                     2.0  ...                                4.0
# 4                     4.0  ...                                1.0
#
#     TEAM_REDCARDS_5_last_match_std  TEAM_OFFSIDES_5_last_match_std  \
# ID
# 0                              0.0                             6.0
# 1                              0.0                             4.0
# 2                              5.0                             6.0
# 3                              0.0                             1.0
# 4                              0.0                             2.0
#
#     TEAM_ATTACKS_5_last_match_std  TEAM_PENALTIES_5_last_match_std  \
# ID
# 0                             0.0                             10.0
# 1                             3.0                             10.0
# 2                             3.0                              6.0
# 3                             8.0                              8.0
# 4                             5.0                              8.0
#
#     TEAM_SUBSTITUTIONS_5_last_match_std  TEAM_BALL_SAFE_5_last_match_std  \
# ID
# 0                                   8.0                              7.0
# 1                                   0.0                              1.0
# 2                                   7.0                              2.0
# 3                                   5.0                              5.0
# 4                                   7.0                              2.0
#
#     TEAM_DANGEROUS_ATTACKS_5_last_match_std  TEAM_INJURIES_5_last_match_std  \
# ID
# 0                                       2.0                             4.0
# 1                                       2.0                             8.0
# 2                                       3.0                             2.0
# 3                                       5.0                             NaN
# 4                                       6.0                             4.0
#
#     TEAM_GOALS_5_last_match_std
# ID
# 0                           3.0
# 1                           4.0
# 2                           4.0
# 3                           6.0
# 4                           4.0
#
# [5 rows x 142 columns]

# %%
train_scores.head()
# Out:
#     HOME_WINS  DRAW  AWAY_WINS
# ID
# 0           0     0          1
# 1           0     1          0
# 2           0     0          1
# 3           1     0          0
# 4           0     1          0

# %% [markdown]
# ## Benchmark
#
# We try to model if AWAY wins

# %%
train_new_y = train_scores['AWAY_WINS']

# %% [markdown]
# ### train, valid test split

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(train_data, train_new_y, train_size=0.8, random_state=42)
X_train, X_valid, y_train, y_valid = model_selection.train_test_split(X_train, y_train, train_size=0.8, random_state=42)

# %% [markdown]
# ### xgb model

# %%
params_1 = {
    'booster': 'gbtree',
    'tree_method':'hist',
    'max_depth': 8, 
    'learning_rate': 0.025,
    'objective': 'multi:softprob',
    'num_class': 2,
    'eval_metric':'mlogloss'
    }


d_train = xgb.DMatrix(X_train.replace({0:np.nan}), y_train)
d_valid = xgb.DMatrix(X_valid.replace({0:np.nan}), y_valid)

num_round = 10000
evallist = [(d_train, 'train'), (d_valid, 'eval')]

bst = xgb.train(params_1, d_train, num_round, evallist, early_stopping_rounds=100)
# Out:
# [0]	train-mlogloss:0.68513	eval-mlogloss:0.68892
# [1]	train-mlogloss:0.67719	eval-mlogloss:0.68483
# [2]	train-mlogloss:0.66953	eval-mlogloss:0.68104
# [3]	train-mlogloss:0.66238	eval-mlogloss:0.67722
# [4]	train-mlogloss:0.65488	eval-mlogloss:0.67373
# [5]	train-mlogloss:0.64817	eval-mlogloss:0.67003
# [6]	train-mlogloss:0.64126	eval-mlogloss:0.66674
# [7]	train-mlogloss:0.63437	eval-mlogloss:0.66369
# [8]	train-mlogloss:0.62811	eval-mlogloss:0.66081
# [9]	train-mlogloss:0.62169	eval-mlogloss:0.65804
# [10]	train-mlogloss:0.61575	eval-mlogloss:0.65558
# [11]	train-mlogloss:0.60954	eval-mlogloss:0.65275
# [12]	train-mlogloss:0.60364	eval-mlogloss:0.65025
# [13]	train-mlogloss:0.59801	eval-mlogloss:0.64800
# [14]	train-mlogloss:0.59252	eval-mlogloss:0.64566
# [15]	train-mlogloss:0.58750	eval-mlogloss:0.64356
# [16]	train-mlogloss:0.58194	eval-mlogloss:0.64121
# [17]	train-mlogloss:0.57636	eval-mlogloss:0.63910
# [18]	train-mlogloss:0.57130	eval-mlogloss:0.63691
# [19]	train-mlogloss:0.56660	eval-mlogloss:0.63482
# [20]	train-mlogloss:0.56200	eval-mlogloss:0.63279
# [21]	train-mlogloss:0.55749	eval-mlogloss:0.63080
# [22]	train-mlogloss:0.55331	eval-mlogloss:0.62943
# [23]	train-mlogloss:0.54852	eval-mlogloss:0.62792
# [24]	train-mlogloss:0.54391	eval-mlogloss:0.62648
# [25]	train-mlogloss:0.53960	eval-mlogloss:0.62484
# [26]	train-mlogloss:0.53550	eval-mlogloss:0.62384
# [27]	train-mlogloss:0.53150	eval-mlogloss:0.62218
# [28]	train-mlogloss:0.52729	eval-mlogloss:0.62120
# [29]	train-mlogloss:0.52333	eval-mlogloss:0.61999
# [30]	train-mlogloss:0.51979	eval-mlogloss:0.61880
# [31]	train-mlogloss:0.51586	eval-mlogloss:0.61763
# [32]	train-mlogloss:0.51220	eval-mlogloss:0.61663
# [33]	train-mlogloss:0.50870	eval-mlogloss:0.61546
# [34]	train-mlogloss:0.50515	eval-mlogloss:0.61439
# [35]	train-mlogloss:0.50187	eval-mlogloss:0.61379
# [36]	train-mlogloss:0.49853	eval-mlogloss:0.61289
# [37]	train-mlogloss:0.49510	eval-mlogloss:0.61205
# [38]	train-mlogloss:0.49193	eval-mlogloss:0.61128
# [39]	train-mlogloss:0.48842	eval-mlogloss:0.61050
# [40]	train-mlogloss:0.48519	eval-mlogloss:0.60971
# [41]	train-mlogloss:0.48222	eval-mlogloss:0.60887
# [42]	train-mlogloss:0.47914	eval-mlogloss:0.60833
# [43]	train-mlogloss:0.47618	eval-mlogloss:0.60756
# [44]	train-mlogloss:0.47304	eval-mlogloss:0.60691
# [45]	train-mlogloss:0.46955	eval-mlogloss:0.60653
# [46]	train-mlogloss:0.46653	eval-mlogloss:0.60582
# [47]	train-mlogloss:0.46360	eval-mlogloss:0.60557
# [48]	train-mlogloss:0.46084	eval-mlogloss:0.60531
# [49]	train-mlogloss:0.45736	eval-mlogloss:0.60502
# [50]	train-mlogloss:0.45453	eval-mlogloss:0.60433
# [51]	train-mlogloss:0.45165	eval-mlogloss:0.60413
# [52]	train-mlogloss:0.44869	eval-mlogloss:0.60363
# [53]	train-mlogloss:0.44594	eval-mlogloss:0.60315
# [54]	train-mlogloss:0.44329	eval-mlogloss:0.60281
# [55]	train-mlogloss:0.44065	eval-mlogloss:0.60246
# [56]	train-mlogloss:0.43758	eval-mlogloss:0.60226
# [57]	train-mlogloss:0.43443	eval-mlogloss:0.60196
# [58]	train-mlogloss:0.43167	eval-mlogloss:0.60169
# [59]	train-mlogloss:0.42874	eval-mlogloss:0.60116
# [60]	train-mlogloss:0.42612	eval-mlogloss:0.60104
# [61]	train-mlogloss:0.42354	eval-mlogloss:0.60089
# [62]	train-mlogloss:0.42056	eval-mlogloss:0.60054
# [63]	train-mlogloss:0.41832	eval-mlogloss:0.60025
# [64]	train-mlogloss:0.41572	eval-mlogloss:0.59964
# [65]	train-mlogloss:0.41323	eval-mlogloss:0.59933
# [66]	train-mlogloss:0.41093	eval-mlogloss:0.59916
# [67]	train-mlogloss:0.40814	eval-mlogloss:0.59891
# [68]	train-mlogloss:0.40596	eval-mlogloss:0.59894
# [69]	train-mlogloss:0.40330	eval-mlogloss:0.59876
# [70]	train-mlogloss:0.40144	eval-mlogloss:0.59847
# [71]	train-mlogloss:0.39859	eval-mlogloss:0.59813
# [72]	train-mlogloss:0.39621	eval-mlogloss:0.59797
# [73]	train-mlogloss:0.39387	eval-mlogloss:0.59798
# [74]	train-mlogloss:0.39142	eval-mlogloss:0.59795
# [75]	train-mlogloss:0.38916	eval-mlogloss:0.59807
# [76]	train-mlogloss:0.38693	eval-mlogloss:0.59784
# [77]	train-mlogloss:0.38460	eval-mlogloss:0.59772
# [78]	train-mlogloss:0.38222	eval-mlogloss:0.59763
# [79]	train-mlogloss:0.38006	eval-mlogloss:0.59760
# [80]	train-mlogloss:0.37779	eval-mlogloss:0.59769
# [81]	train-mlogloss:0.37572	eval-mlogloss:0.59770
# [82]	train-mlogloss:0.37395	eval-mlogloss:0.59783
# [83]	train-mlogloss:0.37183	eval-mlogloss:0.59738
# [84]	train-mlogloss:0.36979	eval-mlogloss:0.59718
# [85]	train-mlogloss:0.36780	eval-mlogloss:0.59699
# [86]	train-mlogloss:0.36580	eval-mlogloss:0.59685
# [87]	train-mlogloss:0.36381	eval-mlogloss:0.59681
# [88]	train-mlogloss:0.36203	eval-mlogloss:0.59686
# [89]	train-mlogloss:0.36035	eval-mlogloss:0.59704
# [90]	train-mlogloss:0.35809	eval-mlogloss:0.59682
# [91]	train-mlogloss:0.35621	eval-mlogloss:0.59664
# [92]	train-mlogloss:0.35434	eval-mlogloss:0.59662
# [93]	train-mlogloss:0.35270	eval-mlogloss:0.59670
# [94]	train-mlogloss:0.35073	eval-mlogloss:0.59691
# [95]	train-mlogloss:0.34910	eval-mlogloss:0.59676
# [96]	train-mlogloss:0.34716	eval-mlogloss:0.59678
# [97]	train-mlogloss:0.34529	eval-mlogloss:0.59651
# [98]	train-mlogloss:0.34353	eval-mlogloss:0.59639
# [99]	train-mlogloss:0.34203	eval-mlogloss:0.59645
# [100]	train-mlogloss:0.33978	eval-mlogloss:0.59636
# [101]	train-mlogloss:0.33833	eval-mlogloss:0.59626
# [102]	train-mlogloss:0.33656	eval-mlogloss:0.59623
# [103]	train-mlogloss:0.33436	eval-mlogloss:0.59598
# [104]	train-mlogloss:0.33240	eval-mlogloss:0.59601
# [105]	train-mlogloss:0.33088	eval-mlogloss:0.59608
# [106]	train-mlogloss:0.32892	eval-mlogloss:0.59627
# [107]	train-mlogloss:0.32723	eval-mlogloss:0.59638
# [108]	train-mlogloss:0.32557	eval-mlogloss:0.59646
# [109]	train-mlogloss:0.32395	eval-mlogloss:0.59653
# [110]	train-mlogloss:0.32192	eval-mlogloss:0.59641
# [111]	train-mlogloss:0.32021	eval-mlogloss:0.59640
# [112]	train-mlogloss:0.31900	eval-mlogloss:0.59656
# [113]	train-mlogloss:0.31747	eval-mlogloss:0.59643
# [114]	train-mlogloss:0.31594	eval-mlogloss:0.59627
# [115]	train-mlogloss:0.31490	eval-mlogloss:0.59622
# [116]	train-mlogloss:0.31374	eval-mlogloss:0.59636
# [117]	train-mlogloss:0.31271	eval-mlogloss:0.59632
# [118]	train-mlogloss:0.31142	eval-mlogloss:0.59646
# [119]	train-mlogloss:0.31043	eval-mlogloss:0.59642
# [120]	train-mlogloss:0.30910	eval-mlogloss:0.59635
# [121]	train-mlogloss:0.30784	eval-mlogloss:0.59662
# [122]	train-mlogloss:0.30662	eval-mlogloss:0.59689
# [123]	train-mlogloss:0.30466	eval-mlogloss:0.59697
# [124]	train-mlogloss:0.30348	eval-mlogloss:0.59693
# [125]	train-mlogloss:0.30186	eval-mlogloss:0.59690
# [126]	train-mlogloss:0.30068	eval-mlogloss:0.59687
# [127]	train-mlogloss:0.29938	eval-mlogloss:0.59677
# [128]	train-mlogloss:0.29763	eval-mlogloss:0.59684
# [129]	train-mlogloss:0.29655	eval-mlogloss:0.59697
# [130]	train-mlogloss:0.29472	eval-mlogloss:0.59717
# [131]	train-mlogloss:0.29333	eval-mlogloss:0.59726
# [132]	train-mlogloss:0.29263	eval-mlogloss:0.59721
# [133]	train-mlogloss:0.29143	eval-mlogloss:0.59732
# [134]	train-mlogloss:0.28990	eval-mlogloss:0.59738
# [135]	train-mlogloss:0.28817	eval-mlogloss:0.59762
# [136]	train-mlogloss:0.28689	eval-mlogloss:0.59765
# [137]	train-mlogloss:0.28550	eval-mlogloss:0.59784
# [138]	train-mlogloss:0.28484	eval-mlogloss:0.59781
# [139]	train-mlogloss:0.28341	eval-mlogloss:0.59784
# [140]	train-mlogloss:0.28186	eval-mlogloss:0.59788
# [141]	train-mlogloss:0.28070	eval-mlogloss:0.59789
# [142]	train-mlogloss:0.27908	eval-mlogloss:0.59782
# [143]	train-mlogloss:0.27775	eval-mlogloss:0.59791
# [144]	train-mlogloss:0.27620	eval-mlogloss:0.59786
# [145]	train-mlogloss:0.27467	eval-mlogloss:0.59798
# [146]	train-mlogloss:0.27346	eval-mlogloss:0.59793
# [147]	train-mlogloss:0.27214	eval-mlogloss:0.59756
# [148]	train-mlogloss:0.27154	eval-mlogloss:0.59752
# [149]	train-mlogloss:0.27045	eval-mlogloss:0.59740
# [150]	train-mlogloss:0.26895	eval-mlogloss:0.59747
# [151]	train-mlogloss:0.26782	eval-mlogloss:0.59746
# [152]	train-mlogloss:0.26644	eval-mlogloss:0.59734
# [153]	train-mlogloss:0.26542	eval-mlogloss:0.59731
# [154]	train-mlogloss:0.26422	eval-mlogloss:0.59748
# [155]	train-mlogloss:0.26323	eval-mlogloss:0.59735
# [156]	train-mlogloss:0.26194	eval-mlogloss:0.59743
# [157]	train-mlogloss:0.26099	eval-mlogloss:0.59749
# [158]	train-mlogloss:0.26034	eval-mlogloss:0.59740
# [159]	train-mlogloss:0.25929	eval-mlogloss:0.59748
# [160]	train-mlogloss:0.25793	eval-mlogloss:0.59764
# [161]	train-mlogloss:0.25670	eval-mlogloss:0.59766
# [162]	train-mlogloss:0.25574	eval-mlogloss:0.59778
# [163]	train-mlogloss:0.25473	eval-mlogloss:0.59801
# [164]	train-mlogloss:0.25350	eval-mlogloss:0.59821
# [165]	train-mlogloss:0.25225	eval-mlogloss:0.59827
# [166]	train-mlogloss:0.25084	eval-mlogloss:0.59849
# [167]	train-mlogloss:0.24964	eval-mlogloss:0.59878
# [168]	train-mlogloss:0.24819	eval-mlogloss:0.59888
# [169]	train-mlogloss:0.24764	eval-mlogloss:0.59892
# [170]	train-mlogloss:0.24651	eval-mlogloss:0.59880
# [171]	train-mlogloss:0.24545	eval-mlogloss:0.59878
# [172]	train-mlogloss:0.24426	eval-mlogloss:0.59881
# [173]	train-mlogloss:0.24297	eval-mlogloss:0.59912
# [174]	train-mlogloss:0.24163	eval-mlogloss:0.59925
# [175]	train-mlogloss:0.24061	eval-mlogloss:0.59936
# [176]	train-mlogloss:0.24006	eval-mlogloss:0.59932
# [177]	train-mlogloss:0.23871	eval-mlogloss:0.59921
# [178]	train-mlogloss:0.23732	eval-mlogloss:0.59936
# [179]	train-mlogloss:0.23681	eval-mlogloss:0.59935
# [180]	train-mlogloss:0.23576	eval-mlogloss:0.59947
# [181]	train-mlogloss:0.23454	eval-mlogloss:0.59951
# [182]	train-mlogloss:0.23326	eval-mlogloss:0.59949
# [183]	train-mlogloss:0.23203	eval-mlogloss:0.59942
# [184]	train-mlogloss:0.23120	eval-mlogloss:0.59961
# [185]	train-mlogloss:0.23010	eval-mlogloss:0.59979
# [186]	train-mlogloss:0.22916	eval-mlogloss:0.60000
# [187]	train-mlogloss:0.22796	eval-mlogloss:0.59995
# [188]	train-mlogloss:0.22721	eval-mlogloss:0.59992
# [189]	train-mlogloss:0.22588	eval-mlogloss:0.60007
# [190]	train-mlogloss:0.22514	eval-mlogloss:0.60007
# [191]	train-mlogloss:0.22382	eval-mlogloss:0.60001
# [192]	train-mlogloss:0.22277	eval-mlogloss:0.59999
# [193]	train-mlogloss:0.22186	eval-mlogloss:0.59991
# [194]	train-mlogloss:0.22096	eval-mlogloss:0.60006
# [195]	train-mlogloss:0.21983	eval-mlogloss:0.60001
# [196]	train-mlogloss:0.21822	eval-mlogloss:0.60029
# [197]	train-mlogloss:0.21738	eval-mlogloss:0.60036
# [198]	train-mlogloss:0.21636	eval-mlogloss:0.60059
# [199]	train-mlogloss:0.21480	eval-mlogloss:0.60068
# [200]	train-mlogloss:0.21382	eval-mlogloss:0.60065
# [201]	train-mlogloss:0.21301	eval-mlogloss:0.60061
# [202]	train-mlogloss:0.21193	eval-mlogloss:0.60082

# %% [markdown]
# ### Some analysis

# %%
xgb.plot_importance(bst, max_num_features=25)
fig = plt.gcf()
fig.set_size_inches(15, 20)

# %% [markdown]
# ### Accuracy on test set

# %% [markdown]
# A simple benchmark is always predicting home wins

# %%
target = train_scores.loc[X_test.index].copy()

home_wins = target
home_wins = 0 * home_wins
home_wins.iloc[:,0] = 1

np.round(accuracy_score(home_wins,target),4)
# Out:
# 0.4401

# %% [markdown]
# Using our model

# %%
X_test_xgb = xgb.DMatrix(X_test)

predictions = bst.predict(X_test_xgb, iteration_range=(0, bst.best_iteration))
predictions = pd.DataFrame(predictions)

predictions[2] = 0
predictions.columns = [0,2,1]
predictions = (predictions.reindex(columns=[0,1,2]).rank(1,ascending=False)==1).astype(int).values
np.round(accuracy_score(predictions,target),4)
# Out:
# 0.4498

# %% [markdown]
# ## Submission

# %%
test_home = pd.read_csv(path_to_data+'Test_data/test_home_team_statistics_df.csv', index_col=0)
test_away = pd.read_csv(path_to_data+'Test_data/test_away_team_statistics_df.csv', index_col=0)

test_home.columns = 'HOME_' + test_home.columns
test_away.columns = 'AWAY_' + test_away.columns

test_data =  pd.concat([test_home,test_away],join='inner',axis=1)

# %%
X_bench = xgb.DMatrix(test_data)

predictions = bst.predict(X_bench, iteration_range=(0, bst.best_iteration))
predictions = pd.DataFrame(predictions)

predictions[2] = 0
predictions.columns = [0,2,1]
predictions = (predictions.reindex(columns=[0,1,2]).rank(1,ascending=False)==1).astype(int)

predictions.columns = ['HOME_WINS', 'DRAW', 'AWAY_WINS']
predictions.index = test_data.index
submission = predictions.reset_index()
submission.to_csv(path_to_data+'benchmark_submission.csv', index=False)
